# %%
import cv2 as cv
import testDataset
import numpy as np
from matplotlib import pyplot as plt
import tensorflow as tf
import tensorlayer as tl
# %matplotlib inline
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-32-33e5ce080551> in <module>
#       1 import cv2 as cv
# ----> 2 import testDataset
#       3 import numpy as np
#       4 from matplotlib import pyplot as plt
#       5 import tensorflow as tf
#
# ModuleNotFoundError: No module named 'testDataset'

# %%
XTrain = dataset.X_train_input
yTrain = dataset.X_train_target[:, :, :, np.newaxis]
x = np.asarray(XTrain[80])
y = np.asarray(yTrain[80])
y_sq = np.squeeze(y)

# %%
plt.imshow(y_sq, cmap = "gray")

# %%
def adjust_gamma(image, gamma=1.0):
    # build a lookup table mapping the pixel values [0, 255] to
    # their adjusted gamma values
    invGamma = 1.0 / gamma
    table = np.array([((i / 255.0) ** invGamma) * 255
        for i in np.arange(0, 256)]).astype("uint8")
 
    # apply gamma correction using the lookup table
    return cv.LUT(image, table)

# %%
def VisualizeImageWithPredictionv2(X, y, path = ""):
    if y.ndim == 2:
        # Then add a dimension to make it have channels
        y = y[:, :, np.newaxis] # (height, width, channel = 1)
    
    assert X.ndim == 3 # Check dimensions of X
    
    # Convert image to uint8
    X = (np.copy(X) * 1.5).astype(np.uint8)
    y = ((y > 0)*255).astype(np.uint8)
    img = np.concatenate((X[:, :, 0, np.newaxis], X[:, :, 1, np.newaxis], X[:, :, 2, np.newaxis], X[:, :, 3, np.newaxis], y), axis = 1)
    img = cv.applyColorMap(img, cv.COLORMAP_HOT)
    cv.imwrite(path, img)

# %%
import os
os.mkdir("./testing1")
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# <ipython-input-30-a1dd140db2db> in <module>
#       1 import os
# ----> 2 os.mkdir("./testing1")
#
# FileExistsError: [WinError 183] Cannot create a file when that file already exists: './testing1'

# %%
VisualizeImageWithPredictionv2(x, y, "test.png")

# %%
for i in range(240):
    for j in range(240):
        if y[i, j] == 1:
            print(y[i,j], i, j)
# Out:
# [1.] 87 70
# [1.] 87 71
# [1.] 87 72
# [1.] 87 73
# [1.] 87 74
# [1.] 87 75
# [1.] 88 66
# [1.] 88 67
# [1.] 88 68
# [1.] 88 69
# [1.] 88 70
# [1.] 88 71
# [1.] 88 72
# [1.] 88 73
# [1.] 88 74
# [1.] 88 75
# [1.] 88 76
# [1.] 88 77
# [1.] 88 78
# [1.] 89 62
# [1.] 89 63
# [1.] 89 64
# [1.] 89 65
# [1.] 89 66
# [1.] 89 67
# [1.] 89 68
# [1.] 89 69
# [1.] 89 70
# [1.] 89 71
# [1.] 89 72
# [1.] 89 73
# [1.] 89 74
# [1.] 89 75
# [1.] 89 76
# [1.] 89 77
# [1.] 89 78
# [1.] 89 79
# [1.] 89 80
# [1.] 90 60
# [1.] 90 61
# [1.] 90 62
# [1.] 90 63
# [1.] 90 64
# [1.] 90 65
# [1.] 90 66
# [1.] 90 67
# [1.] 90 68
# [1.] 90 69
# [1.] 90 70
# [1.] 90 71
# [1.] 90 72
# [1.] 90 73
# [1.] 90 74
# [1.] 90 75
# [1.] 90 76
# [1.] 90 77
# [1.] 90 78
# [1.] 90 79
# [1.] 90 80
# [1.] 90 81
# [1.] 90 82
# [1.] 91 57
# [1.] 91 58
# [1.] 91 59
# [1.] 91 60
# [1.] 91 61
# [1.] 91 62
# [1.] 91 63
# [1.] 91 64
# [1.] 91 65
# [1.] 91 66
# [1.] 91 67
# [1.] 91 68
# [1.] 91 69
# [1.] 91 70
# [1.] 91 71
# ...

# %%
VisualizeImageWithPredictionv2(XTrain[82, :, :, :], (yTrain[82, :, : , :] > 0), "test.png")

# %%
(yTrain > 0).astype(int)
